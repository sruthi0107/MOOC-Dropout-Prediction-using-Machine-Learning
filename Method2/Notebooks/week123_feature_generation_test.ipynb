# %%
import pandas as pd
import os
import numpy as np
import datetime
from datetime import date

# %%
truth_test = pd.read_csv("test/truth_test.csv")
truth_enroll = truth_test['2'].to_list()

# %%
required_test_users = pd.read_csv("required_test_users.csv")
required_test_users.drop('Unnamed: 0', axis=1, inplace=True)
#required_test_users = required_test_users.head(200) # Remove when running full dataset

# %%
required_test_users
# Out:
#        enrollment_id                          username  \
# 0                 34  OeLBIzS0gNQ56euxy5b66gAZMzQCGE7n
# 1                 66  cGrHiRjztN9fSltHujpfWaaWfYWiidiG
# 2                 85  OdsEBh425XZxll0hTUv04OAotDf6aGtE
# 3                 89  Po17baTutQqG3KBkMaahpxQ7IpjhFfZa
# 4                108  tIzV4oVJd7GebOZj2uw51WJCx59QGqJ5
# ...              ...                               ...
# 14347         200782  hyOYv4rmSRnv16UkVW9gdxwUgBZxYdhv
# 14348         200800  7nzr7mwsX3K7BiOtdIcVBSR6zEXVIYI1
# 14349         200806  4h79uMcS1iYROsRps1078ngx78w376cH
# 14350         200817  vDNo4mQAZOC4PWVxrxTTUTLEt0bpNinW
# 14351         200829  JLn36xalC1eIUd4jm6gux9oEgx3gpDxA
#
#                               course_id
# 0      7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 1      7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 2      7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 3      7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 4      5X6FeZozNMgE2VRi3MJYjkkFK8SETtu2
# ...                                 ...
# 14347  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 14348  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 14349  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 14350  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 14351  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
#
# [14352 rows x 3 columns]

# %%
enrollment_id_list = required_test_users['enrollment_id'].to_list()

# %%
week123 = pd.read_csv('week123_test.csv')
week123
# Out:
#         Unnamed: 0.1  Unnamed: 0  enrollment_id                 time  source  \
# 0                  0        2650             34  2014-06-22T15:58:19  server
# 1                  1        2651             34  2014-06-22T16:00:51  server
# 2                  2        2652             34  2014-06-22T16:00:52  server
# 3                  3        2653             34  2014-06-22T16:00:58  server
# 4                  4        2654             34  2014-06-22T16:02:03  server
# ...              ...         ...            ...                  ...     ...
# 486566        866745     5384283         200176  2014-02-06T13:10:31  server
# 486567        866746     5384284         200176  2014-02-06T13:10:31  server
# 486568        866747     5384285         200176  2014-02-06T13:10:39  server
# 486569        866748     5384286         200176  2014-02-06T13:10:43  server
# 486570        866749     5384287         200176  2014-02-06T13:10:49  server
#
#              event                            object        date time_event
# 0         navigate  Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-06-22   15:58:19
# 1         navigate  l0kj1vWrjGxi2YqQWGitPXDEoH5G5RYd  2014-06-22   16:00:51
# 2             wiki  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-22   16:00:52
# 3         navigate  a8k7VowQW6MVkImzpiv8bqd9BAdOwCKb  2014-06-22   16:00:58
# 4           access  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-22   16:02:03
# ...            ...                               ...         ...        ...
# 486566    navigate  l0kj1vWrjGxi2YqQWGitPXDEoH5G5RYd  2014-02-06   13:10:31
# 486567        wiki  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-02-06   13:10:31
# 486568    navigate  vPJ7ada7OqDfvYXMjnTQC3NExmLvWiUL  2014-02-06   13:10:39
# 486569    navigate  ykjH1bzwnUL5biZCKZGrCwLbCJ3znUdx  2014-02-06   13:10:43
# 486570  discussion  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-02-06   13:10:49
#
# [486571 rows x 9 columns]

# %%
week123.drop('Unnamed: 0', axis=1, inplace=True)
week123
# Out:
#         Unnamed: 0.1  enrollment_id                 time  source       event  \
# 0                  0             34  2014-06-22T15:58:19  server    navigate
# 1                  1             34  2014-06-22T16:00:51  server    navigate
# 2                  2             34  2014-06-22T16:00:52  server        wiki
# 3                  3             34  2014-06-22T16:00:58  server    navigate
# 4                  4             34  2014-06-22T16:02:03  server      access
# ...              ...            ...                  ...     ...         ...
# 486566        866745         200176  2014-02-06T13:10:31  server    navigate
# 486567        866746         200176  2014-02-06T13:10:31  server        wiki
# 486568        866747         200176  2014-02-06T13:10:39  server    navigate
# 486569        866748         200176  2014-02-06T13:10:43  server    navigate
# 486570        866749         200176  2014-02-06T13:10:49  server  discussion
#
#                                   object        date time_event
# 0       Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-06-22   15:58:19
# 1       l0kj1vWrjGxi2YqQWGitPXDEoH5G5RYd  2014-06-22   16:00:51
# 2       3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-22   16:00:52
# 3       a8k7VowQW6MVkImzpiv8bqd9BAdOwCKb  2014-06-22   16:00:58
# 4       3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-22   16:02:03
# ...                                  ...         ...        ...
# 486566  l0kj1vWrjGxi2YqQWGitPXDEoH5G5RYd  2014-02-06   13:10:31
# 486567  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-02-06   13:10:31
# 486568  vPJ7ada7OqDfvYXMjnTQC3NExmLvWiUL  2014-02-06   13:10:39
# 486569  ykjH1bzwnUL5biZCKZGrCwLbCJ3znUdx  2014-02-06   13:10:43
# 486570  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-02-06   13:10:49
#
# [486571 rows x 8 columns]

# %%
features123 = []
enrollment_id1 = []
week123_len = len(week123)
for i in range(week123_len):
    e_id = week123.loc[i, 'enrollment_id']
    if e_id not in enrollment_id1:
        enrollment_id1.append(e_id)
#enrollment_id1 = enrollment_id1[:2]
for eid in enrollment_id1:
    i = enrollment_id_list.index(eid)
    truth_index = truth_enroll.index(eid)
    temp123 = [eid, required_test_users.loc[i, 'username'], required_test_users.loc[i, 'course_id']]+[0]*23+[truth_test.loc[truth_index, '0']]
    features123.append(temp123)
unique_enroll = len(enrollment_id1)

# %%
unique_enroll
# Out:
# 8997

# %%
# Feature 1 - Number of participating objects of course per week
objs = {}
for i in range(week123_len):
    ob = week123.loc[i, 'object']
    eid = week123.loc[i, 'enrollment_id']
    index = enrollment_id1.index(eid)
    if eid not in objs:
        objs[eid] = [ob]
        features123[index][3] += 1
    else:
        if ob not in objs[eid]:
            objs[eid].append(ob)
            features123[index][3] += 1

# %%
# Feature 2-8 - Behaviour number of access, page_close, problem video, discussion, navigate, wiki
for i in range(week123_len):
    eid = week123.loc[i, 'enrollment_id']
    event = week123.loc[i, 'event']
    index = enrollment_id1.index(eid)
    if event == 'access':
        features123[index][4] += 1
    elif event == 'page_close':
        features123[index][5] += 1
    elif event == 'problem':
        features123[index][6] += 1
    elif event == 'video':
        features123[index][7] += 1
    elif event == 'discussion':
        features123[index][8] += 1
    elif event == 'navigate':
        features123[index][9] += 1
    else:
        features123[index][10] += 1  # wiki

# %%
# Feature 9-10 - The total and average numbers of all behaviors per week
for i in range(unique_enroll):
    behaviour_list = features123[i][4:11]
    features123[i][11] = sum(behaviour_list) # Total behaviours per week
    features123[i][12] = features123[i][11]/7   # Average behaviours per week

# %%
# Feature 11 - Number of active days per week
active_dates = {}
for i in range(week123_len):
    d = week123.loc[i, 'date']
    eid = week123.loc[i, 'enrollment_id']
    index = enrollment_id1.index(eid)
    if eid not in active_dates:
        active_dates[eid] = [d]
        features123[index][13] += 1
    else:
        if d not in active_dates[eid]:
            active_dates[eid].append(d)
            features123[index][13] += 1

# %%
# Feature 12 - Time consumption per week
t1 = pd.to_datetime(week123.loc[0, 'time'], infer_datetime_format=True)
e1 = week123.loc[0, 'enrollment_id']
d1 = week123.loc[0, 'date']
for i in range(1, week123_len):
    t2 = pd.to_datetime(week123.loc[i, 'time'], infer_datetime_format=True)
    e2 = week123.loc[1, 'enrollment_id']
    d2 = week123.loc[1, 'date']
    index = enrollment_id1.index(e2)
    if e1==e2 and d1==d2:
        delta = (t2 - t1).total_seconds()
        features123[index][14] += delta
    t1 = t2
    e1 = e2
    d1 = d2

# %%
# Feature 13-16 - The behavior numbers of access, page close, problem, video from browser per week respectively.
for i in range(week123_len):
    eid = week123.loc[i, 'enrollment_id']
    source = week123.loc[i, 'source']
    event = week123.loc[i, 'event']
    index = enrollment_id1.index(eid)
    if source=='browser':
        if event == 'access':
            features123[index][15] += 1
        elif event == 'page_close':
            features123[index][16] += 1
        elif event == 'problem':
            features123[index][17] += 1
        elif event == 'video':
            features123[index][18] += 1

# %%
# Feature 17-21 - The behavior numbers of access, discussion, problem, navigating, wiki from server per week respectively
for i in range(week123_len):
    eid = week123.loc[i, 'enrollment_id']
    source = week123.loc[i, 'source']
    event = week123.loc[i, 'event']
    index = enrollment_id1.index(eid)
    if source=='server':
        if event == 'access':
            features123[index][19] += 1
        elif event == 'discussion':
            features123[index][20] += 1
        elif event == 'problem':
            features123[index][21] += 1
        elif event == 'navigate':
            features123[index][22] += 1
        elif event == 'wiki':
            features123[index][23] += 1  # wiki

# %%
# Feature 22-23 - The numbers of all behaviors from browser and server per week respectively
for i in range(unique_enroll):
    browser_list = features123[i][15:19]
    features123[i][24] = sum(browser_list) # Total behaviours from browser per week
    server_list = features123[i][19:24]
    features123[i][25] = sum(server_list) # Total behaviours from server per week

# %%
cols = ['enrollment_id',
        'username',
        'course_id',
        'no_of_objects123',
        'bno_access123',
        'bno_pageclose123',
        'bno_problem123',
        'bno_video123',
        'bno_discussion123',
        'bno_navigate123',
        'bno_wiki123',
        'bno_total123',
        'bno_avg123',
        'no_of_active_days123',
        'time_consumption123',
        'browser_access123',
        'browser_pageclose123',
        'browser_problem123',
        'browser_video123',
        'server_access123',
        'server_discussion123',
        'server_problem123',
        'server_navigate123',
        'server_wiki123',
        'bno_browser123',
        'bno_server123',
        'label']
        
features_week123 = pd.DataFrame(features123, columns = cols)

# %%
features_week123
# Out:
#       enrollment_id                          username  \
# 0                34  OeLBIzS0gNQ56euxy5b66gAZMzQCGE7n
# 1                66  cGrHiRjztN9fSltHujpfWaaWfYWiidiG
# 2                85  OdsEBh425XZxll0hTUv04OAotDf6aGtE
# 3                89  Po17baTutQqG3KBkMaahpxQ7IpjhFfZa
# 4               145  TZOWoG0yzTTzAfx5K054mpl5rZTlZIcZ
# ...             ...                               ...
# 8992         200168  AYthRqjUqxgBOMkMdZlsA0hn0RkYMhX1
# 8993         200170  8uvIif4A5L5EPYASYSg4Tx0sVAF45af4
# 8994         200172  TNhUrfYcya3yxRpJxMcmjGjIL7iLVR1R
# 8995         200174  5OFiMxDgE4Mm8y2SD0A2gGR1Jne1kbKh
# 8996         200176  pzhB8LO3WWjbU215lU1c8Ly5btvgYfuP
#
#                              course_id  no_of_objects123  bno_access123  \
# 0     7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx                71            152
# 1     7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx               100            386
# 2     7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx                10             14
# 3     7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx                52            133
# 4     7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx                61            187
# ...                                ...               ...            ...
# 8992  fbPkOYLVPtPgIt0MxizjfFJov3JbHyAi                11             14
# 8993  fbPkOYLVPtPgIt0MxizjfFJov3JbHyAi                 2              2
# 8994  fbPkOYLVPtPgIt0MxizjfFJov3JbHyAi                 1              0
# 8995  fbPkOYLVPtPgIt0MxizjfFJov3JbHyAi                 4              2
# 8996  fbPkOYLVPtPgIt0MxizjfFJov3JbHyAi                 6              0
#
#       bno_pageclose123  bno_problem123  bno_video123  bno_discussion123  \
# 0                   42             110            33                  8
# 1                   73             205            39                258
# 2                    4               2             3                  0
# 3                    7              95            30                 11
# 4                   63              96            37                 31
# ...                ...             ...           ...                ...
# 8992                 9               0             8                  1
# 8993                 0               0             0                  0
# 8994                 0               0             0                  0
# 8995                 1               0             0                  0
# 8996                 0               0             0                  2
#
#       bno_navigate123  ...  browser_problem123  browser_video123  \
# 0                  37  ...                  95                33
# 1                  49  ...                 159                39
# 2                   5  ...                   2                 3
# 3                   8  ...                  81                30
# 4                  16  ...                  88                37
# ...               ...  ...                 ...               ...
# 8992                3  ...                   0                 8
# 8993                0  ...                   0                 0
# 8994                1  ...                   0                 0
# 8995                2  ...                   0                 0
# 8996                7  ...                   0                 0
#
#       server_access123  server_discussion123  server_problem123  \
# 0                   69                     8                 15
# 1                  244                   258                 46
# 2                   13                     0                  0
# 3                   57                    11                 14
# 4                  131                    31                  8
# ...                ...                   ...                ...
# 8992                11                     1                  0
# 8993                 2                     0                  0
# 8994                 0                     0                  0
# 8995                 2                     0                  0
# 8996                 0                     2                  0
#
#       server_navigate123  server_wiki123  bno_browser123  bno_server123  label
# 0                     37               3             253            132      0
# 1                     49               0             413            597      0
# 2                      5               0              10             18      1
# 3                      8               0             194             90      1
# 4                     16               4             244            190      1
# ...                  ...             ...             ...            ...    ...
# 8992                   3               0              20             15      1
# 8993                   0               0               0              2      1
# 8994                   1               0               0              1      1
# 8995                   2               0               1              4      1
# 8996                   7               1               0             10      1
#
# [8997 rows x 27 columns]

# %%
features_week123.to_csv('features_week123_test.csv')
