# %%
import pandas as pd
import os
import numpy as np
import datetime
from datetime import date

# %%
obj = pd.read_csv("object.csv")
datefile = pd.read_csv("date.csv")
e_test = pd.read_csv("test/enrollment_test.csv")
log_test = pd.read_csv("test/log_test.csv")
truth_test = pd.read_csv("test/truth_test.csv")

# %%
truth_test
# Out:
#             2  0
# 0           8  0
# 1          10  1
# 2          11  0
# 3          15  0
# 4          17  0
# ...       ... ..
# 80356  200892  1
# 80357  200894  1
# 80358  200899  1
# 80359  200902  1
# 80360  200903  1
#
# [80361 rows x 2 columns]

# %%
truth_enroll = truth_test['2'].to_list()
truth_enroll
# Out:
# [8,
#  10,
#  11,
#  15,
#  17,
#  19,
#  21,
#  24,
#  25,
#  27,
#  29,
#  33,
#  34,
#  36,
#  37,
#  38,
#  40,
#  41,
#  42,
#  43,
#  44,
#  47,
#  52,
#  56,
#  57,
#  59,
#  61,
#  62,
#  63,
#  64,
#  66,
#  72,
#  77,
#  79,
#  84,
#  85,
#  89,
#  91,
#  99,
#  100,
#  105,
#  108,
#  110,
#  115,
#  116,
#  117,
#  118,
#  124,
#  125,
#  126,
#  127,
#  128,
#  136,
#  137,
#  139,
#  145,
#  147,
#  153,
#  154,
#  158,
#  163,
#  165,
#  168,
#  169,
#  177,
#  179,
#  181,
#  183,
#  184,
#  185,
#  187,
#  188,
#  191,
#  194,
#  197,
#  202,
#  203,
#  205,
#  206,
#  207,
#  210,
#  211,
#  213,
#  215,
#  217,
#  218,
#  220,
#  224,
#  225,
#  229,
#  232,
#  236,
#  237,
#  238,
#  243,
#  246,
#  253,
#  259,
#  260,
#  263,
#  271,
#  273,
#  274,
#  276,
#  283,
#  287,
#  289,
#  290,
#  291,
#  292,
#  296,
#  299,
#  300,
#  303,
#  306,
#  308,
#  312,
#  318,
#  326,
#  328,
#  330,
#  331,
#  333,
#  336,
#  342,
#  347,
#  348,
#  350,
#  356,
#  359,
#  362,
#  363,
#  365,
#  368,
#  369,
#  372,
#  374,
#  376,
#  378,
#  380,
#  381,
#  383,
#  384,
#  385,
#  388,
#  389,
#  391,
#  392,
#  395,
#  397,
#  401,
#  404,
#  405,
#  408,
#  409,
#  411,
#  413,
#  415,
#  416,
#  417,
#  418,
#  422,
#  423,
#  427,
#  430,
#  434,
#  437,
#  439,
#  440,
#  443,
#  449,
#  453,
#  455,
#  456,
#  457,
#  462,
#  465,
#  468,
#  470,
#  472,
#  473,
#  476,
#  477,
#  478,
#  479,
#  481,
#  483,
#  485,
#  488,
#  489,
#  492,
#  494,
#  495,
#  498,
#  499,
#  502,
#  503,
#  504,
#  506,
#  508,
#  510,
#  513,
#  519,
#  521,
#  524,
#  528,
#  529,
#  531,
#  537,
#  538,
#  539,
#  540,
#  542,
#  544,
#  549,
#  551,
#  554,
#  557,
#  559,
#  560,
#  563,
#  564,
#  565,
#  567,
#  568,
#  569,
#  570,
#  571,
#  573,
#  574,
#  575,
#  577,
#  578,
#  585,
#  586,
#  593,
#  595,
#  596,
#  597,
#  601,
#  604,
#  605,
#  607,
#  608,
#  610,
#  618,
#  619,
#  622,
#  623,
#  624,
#  626,
#  628,
#  631,
#  632,
#  637,
#  640,
#  641,
#  642,
#  647,
#  648,
#  649,
#  651,
#  653,
#  655,
#  656,
#  657,
#  664,
#  665,
#  666,
#  669,
#  670,
#  671,
#  672,
#  674,
#  675,
#  678,
#  679,
#  681,
#  684,
#  688,
#  694,
#  696,
#  698,
#  702,
#  706,
#  708,
#  710,
#  716,
#  720,
#  729,
#  732,
#  735,
#  737,
#  739,
#  741,
#  747,
#  748,
#  754,
#  755,
#  759,
#  764,
#  765,
#  766,
#  767,
#  770,
#  772,
#  776,
#  779,
#  782,
#  784,
#  786,
#  787,
#  794,
#  795,
#  798,
#  801,
#  807,
#  808,
#  811,
#  812,
#  813,
#  814,
#  816,
#  817,
#  823,
#  826,
#  828,
#  829,
#  831,
#  832,
#  834,
#  836,
#  842,
#  846,
#  847,
#  849,
#  851,
#  855,
#  856,
#  857,
#  859,
#  864,
#  866,
#  867,
#  869,
#  874,
#  876,
#  879,
#  880,
#  881,
#  883,
#  886,
#  889,
#  892,
#  894,
#  896,
#  897,
#  898,
#  902,
#  905,
#  908,
#  909,
#  910,
#  913,
#  914,
#  915,
#  918,
#  920,
#  926,
#  927,
#  928,
#  929,
#  931,
#  932,
#  934,
#  943,
#  944,
#  947,
#  948,
#  949,
#  957,
#  959,
#  968,
#  969,
#  972,
#  973,
#  975,
#  977,
#  979,
#  981,
#  982,
#  983,
#  986,
#  990,
#  993,
#  995,
#  998,
#  1003,
#  1004,
#  1009,
#  1010,
#  1012,
#  1013,
#  1014,
#  1016,
#  1017,
#  1025,
#  1026,
#  1027,
#  1032,
#  1034,
#  1036,
#  1038,
#  1039,
#  1042,
#  1047,
#  1048,
#  1051,
#  1053,
#  1055,
#  1059,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1067,
#  1068,
#  1070,
#  1071,
#  1079,
#  1081,
#  1083,
#  1093,
#  1094,
#  1097,
#  1100,
#  1102,
#  1104,
#  1105,
#  1106,
#  1109,
#  1111,
#  1113,
#  1114,
#  1115,
#  1117,
#  1119,
#  1120,
#  1121,
#  1122,
#  1123,
#  1125,
#  1127,
#  1130,
#  1132,
#  1146,
#  1148,
#  1151,
#  1152,
#  1155,
#  1156,
#  1157,
#  1159,
#  1160,
#  1161,
#  1165,
#  1166,
#  1171,
#  1173,
#  1175,
#  1184,
#  1189,
#  1193,
#  1194,
#  1197,
#  1198,
#  1200,
#  1205,
#  1207,
#  1208,
#  1209,
#  1210,
#  1211,
#  1214,
#  1215,
#  1217,
#  1218,
#  1219,
#  1220,
#  1221,
#  1224,
#  1226,
#  1229,
#  1231,
#  1232,
#  1234,
#  1236,
#  1237,
#  1238,
#  1239,
#  1242,
#  1245,
#  1247,
#  1251,
#  1254,
#  1256,
#  1259,
#  1261,
#  1262,
#  1265,
#  1266,
#  1267,
#  1272,
#  1275,
#  1276,
#  1277,
#  1279,
#  1282,
#  1286,
#  1291,
#  1293,
#  1294,
#  1298,
#  1300,
#  1302,
#  1304,
#  1305,
#  1307,
#  1314,
#  1317,
#  1319,
#  1320,
#  1324,
#  1325,
#  1326,
#  1327,
#  1329,
#  1330,
#  1332,
#  1333,
#  1334,
#  1335,
#  1336,
#  1338,
#  1346,
#  1347,
#  1354,
#  1355,
#  1356,
#  1359,
#  1360,
#  1361,
#  1362,
#  1368,
#  1369,
#  1370,
#  1374,
#  1375,
#  1382,
#  1383,
#  1384,
#  1385,
#  1388,
#  1395,
#  1396,
#  1400,
#  1403,
#  1411,
#  1415,
#  1416,
#  1419,
#  1421,
#  1426,
#  1432,
#  1434,
#  1435,
#  1436,
#  1439,
#  1445,
#  1447,
#  1448,
#  1449,
#  1459,
#  1461,
#  1467,
#  1470,
#  1471,
#  1475,
#  1479,
#  1482,
#  1483,
#  1487,
#  1492,
#  1505,
#  1507,
#  1510,
#  1511,
#  1514,
#  1515,
#  1517,
#  1523,
#  1526,
#  1527,
#  1528,
#  1531,
#  1534,
#  1539,
#  1540,
#  1543,
#  1544,
#  1547,
#  1552,
#  1553,
#  1554,
#  1555,
#  1559,
#  1560,
#  1563,
#  1566,
#  1568,
#  1570,
#  1571,
#  1574,
#  1577,
#  1580,
#  1584,
#  1586,
#  1589,
#  1590,
#  1591,
#  1596,
#  1598,
#  1599,
#  1603,
#  1605,
#  1611,
#  1613,
#  1619,
#  1623,
#  1624,
#  1626,
#  1635,
#  1636,
#  1638,
#  1641,
#  1642,
#  1643,
#  1644,
#  1646,
#  1655,
#  1656,
#  1658,
#  1659,
#  1661,
#  1664,
#  1665,
#  1666,
#  1667,
#  1670,
#  1671,
#  1675,
#  1680,
#  1682,
#  1683,
#  1684,
#  1689,
#  1691,
#  1693,
#  1695,
#  1696,
#  1699,
#  1702,
#  1704,
#  1706,
#  1709,
#  1710,
#  1712,
#  1716,
#  1717,
#  1718,
#  1721,
#  1723,
#  1726,
#  1727,
#  1729,
#  1737,
#  1739,
#  1741,
#  1742,
#  1743,
#  1744,
#  1746,
#  1748,
#  1750,
#  1759,
#  1761,
#  1762,
#  1765,
#  1766,
#  1768,
#  1771,
#  1773,
#  1774,
#  1775,
#  1777,
#  1778,
#  1781,
#  1784,
#  1786,
#  1787,
#  1791,
#  1797,
#  1798,
#  1802,
#  1808,
#  1809,
#  1810,
#  1814,
#  1820,
#  1824,
#  1825,
#  1834,
#  1836,
#  1837,
#  1839,
#  1840,
#  1841,
#  1843,
#  1846,
#  1847,
#  1848,
#  1850,
#  1851,
#  1853,
#  1854,
#  1855,
#  1857,
#  1858,
#  1860,
#  1866,
#  1868,
#  1877,
#  1881,
#  1884,
#  1885,
#  1887,
#  1889,
#  1890,
#  1892,
#  1896,
#  1897,
#  1898,
#  1900,
#  1904,
#  1905,
#  1907,
#  1908,
#  1912,
#  1914,
#  1916,
#  1919,
#  1920,
#  1921,
#  1924,
#  1925,
#  1927,
#  1930,
#  1935,
#  1937,
#  1942,
#  1944,
#  1946,
#  1954,
#  1955,
#  1957,
#  1958,
#  1961,
#  1962,
#  1965,
#  1969,
#  1972,
#  1976,
#  1978,
#  1982,
#  1984,
#  1985,
#  1987,
#  1988,
#  1992,
#  1993,
#  1994,
#  1999,
#  2000,
#  2002,
#  2006,
#  2011,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2021,
#  2022,
#  2024,
#  2027,
#  2029,
#  2030,
#  2031,
#  2032,
#  2033,
#  2035,
#  2036,
#  2038,
#  2041,
#  2042,
#  2044,
#  2046,
#  2053,
#  2056,
#  2057,
#  2060,
#  2061,
#  2068,
#  2071,
#  2073,
#  2075,
#  2078,
#  2080,
#  2082,
#  2083,
#  2084,
#  2087,
#  2091,
#  2096,
#  2101,
#  2106,
#  2111,
#  2112,
#  2115,
#  2118,
#  2119,
#  2122,
#  2123,
#  2125,
#  2127,
#  2130,
#  2133,
#  2136,
#  2138,
#  2139,
#  2141,
#  2142,
#  2143,
#  2145,
#  2146,
#  2147,
#  2149,
#  2150,
#  2151,
#  2154,
#  2157,
#  2163,
#  2164,
#  2165,
#  2172,
#  2174,
#  2175,
#  2180,
#  2183,
#  2193,
#  2196,
#  2200,
#  2204,
#  2205,
#  2207,
#  2211,
#  2212,
#  2216,
#  2218,
#  2221,
#  2223,
#  2226,
#  2231,
#  2237,
#  2238,
#  2243,
#  2244,
#  2250,
#  2252,
#  2254,
#  2256,
#  2267,
#  2268,
#  2269,
#  2270,
#  2272,
#  2275,
#  2276,
#  2277,
#  2278,
#  2280,
#  2282,
#  2286,
#  2289,
#  2293,
#  2298,
#  2303,
#  2305,
#  2306,
#  2310,
#  2311,
#  2314,
#  2315,
#  2320,
#  2322,
#  2324,
#  2325,
#  2326,
#  2328,
#  2329,
#  2330,
#  2336,
#  2337,
#  2340,
#  2343,
#  2345,
#  2346,
#  2348,
#  2349,
#  2350,
#  2352,
#  2353,
#  2356,
#  2357,
#  2360,
#  2363,
#  2366,
#  2369,
#  2371,
#  2373,
#  2374,
#  2376,
#  2377,
#  2378,
#  2380,
#  2381,
#  2382,
#  2383,
#  2384,
#  2387,
#  2388,
#  2391,
#  2392,
#  2395,
#  2398,
#  2400,
#  2405,
#  2408,
#  2409,
#  2410,
#  2412,
#  2413,
#  2414,
#  2419,
#  2421,
#  2422,
#  2423,
#  2424,
#  2427,
#  2431,
#  2433,
#  2437,
#  2438,
#  2442,
#  2443,
#  2444,
#  2446,
#  2447,
#  2450,
#  2451,
#  2452,
#  2453,
#  2456,
#  2457,
#  2461,
#  2462,
#  2465,
#  2467,
#  2471,
#  2473,
#  2477,
#  2478,
#  2480,
#  2483,
#  2486,
#  2489,
#  2491,
#  2493,
#  ...]

# %%
courses = datefile.head(10)
course_id_list = courses['course_id'].to_list()

# %%
start_end_dates = pd.read_csv("start_end_dates.csv")
start_end_dates
# Out:
#    Unnamed: 0                         course_id week1_start   week1_end  \
# 0           0  bWdj2GDclj5ofokWjzoa5jAwMkxCykd6  2014-05-26  2014-06-01
# 1           1  RXDvfPUBYFlVdlueBFbLW0mhhAyGEqpt  2014-05-25  2014-05-31
# 2           2  fbPkOYLVPtPgIt0MxizjfFJov3JbHyAi  2014-01-17  2014-01-23
# 3           3  A3fsA9Zfv1X2fVEQhTw51lKENdNrEqT3  2014-05-28  2014-06-03
# 4           4  5X6FeZozNMgE2VRi3MJYjkkFK8SETtu2  2014-09-06  2014-09-12
# 5           5  5Gyp41oLVo7Gg7vF4vpmggWP5MU70QO6  2013-11-12  2013-11-18
# 6           6  SpATywNh6bZuzm8s1ceuBUnMUAeoAHHw  2014-05-26  2014-06-01
# 7           7  3VkHkmOtom3jM2wCu94xgzzu1d6Dn7or  2013-01-11  2013-01-17
# 8           8  G8EPVSXsOYB5YQWZGiz1aVq5Pgr2GrQu  2014-05-25  2014-05-31
# 9           9  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx  2014-06-19  2014-06-25
#
#   week2_start   week2_end week3_start   week3_end week4_start   week4_end
# 0  2014-06-02  2014-06-08  2014-06-09  2014-06-15  2014-06-16  2014-06-24
# 1  2014-06-01  2014-06-07  2014-06-08  2014-06-14  2014-06-15  2014-06-23
# 2  2014-01-24  2014-01-30  2014-01-31  2014-02-06  2014-02-07  2014-02-15
# 3  2014-06-04  2014-06-10  2014-06-11  2014-06-17  2014-06-18  2014-06-26
# 4  2014-09-13  2014-09-19  2014-09-20  2014-09-26  2014-09-27  2014-08-07
# 5  2013-11-19  2013-11-25  2013-11-26  2013-12-02  2013-12-03  2014-09-01
# 6  2014-06-02  2014-06-08  2014-06-09  2014-06-15  2014-06-16  2014-06-24
# 7  2013-01-18  2013-01-24  2013-01-25  2013-01-31  2013-02-01  2013-11-30
# 8  2014-06-01  2014-06-07  2014-06-08  2014-06-14  2014-06-15  2014-06-23
# 9  2014-06-26  2014-07-02  2014-07-03  2014-07-09  2014-07-10  2014-07-18

# %%
start_end_dates.drop('Unnamed: 0', axis=1, inplace=True)

# %%
from datetime import date
for i in range(len(start_end_dates)):
    d1 = start_end_dates.loc[i,'week1_start'].split('-')
    start_end_dates.at[i,'week1_start'] = date(int(d1[0]), int(d1[1]), int(d1[2]))
    d2 = start_end_dates.loc[i,'week1_end'].split('-')
    start_end_dates.at[i,'week1_end'] = date(int(d2[0]), int(d2[1]), int(d2[2]))
    d3 = start_end_dates.loc[i,'week2_start'].split('-')
    start_end_dates.at[i,'week2_start'] = date(int(d3[0]), int(d3[1]), int(d3[2]))
    d4 = start_end_dates.loc[i,'week2_end'].split('-')
    start_end_dates.at[i,'week2_end'] = date(int(d4[0]), int(d4[1]), int(d4[2]))
    d5 = start_end_dates.loc[i,'week3_start'].split('-')
    start_end_dates.at[i,'week3_start'] = date(int(d5[0]), int(d5[1]), int(d5[2]))
    d6 = start_end_dates.loc[i,'week3_end'].split('-')
    start_end_dates.at[i,'week3_end'] = date(int(d6[0]), int(d6[1]), int(d6[2]))
    d7 = start_end_dates.loc[i,'week4_start'].split('-')
    start_end_dates.at[i,'week4_start'] = date(int(d7[0]), int(d7[1]), int(d7[2]))
    d8 = start_end_dates.loc[i,'week4_end'].split('-')
    start_end_dates.at[i,'week4_end'] = date(int(d8[0]), int(d8[1]), int(d8[2]))

# %%
required_test_users = pd.read_csv("required_test_users.csv")
required_test_users.drop('Unnamed: 0', axis=1, inplace=True)
#required_test_users = required_test_users.head(10000) # Remove when running full dataset

# %%
required_test_users
# Out:
#        enrollment_id                          username  \
# 0                 34  OeLBIzS0gNQ56euxy5b66gAZMzQCGE7n
# 1                 66  cGrHiRjztN9fSltHujpfWaaWfYWiidiG
# 2                 85  OdsEBh425XZxll0hTUv04OAotDf6aGtE
# 3                 89  Po17baTutQqG3KBkMaahpxQ7IpjhFfZa
# 4                108  tIzV4oVJd7GebOZj2uw51WJCx59QGqJ5
# ...              ...                               ...
# 14347         200782  hyOYv4rmSRnv16UkVW9gdxwUgBZxYdhv
# 14348         200800  7nzr7mwsX3K7BiOtdIcVBSR6zEXVIYI1
# 14349         200806  4h79uMcS1iYROsRps1078ngx78w376cH
# 14350         200817  vDNo4mQAZOC4PWVxrxTTUTLEt0bpNinW
# 14351         200829  JLn36xalC1eIUd4jm6gux9oEgx3gpDxA
#
#                               course_id
# 0      7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 1      7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 2      7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 3      7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 4      5X6FeZozNMgE2VRi3MJYjkkFK8SETtu2
# ...                                 ...
# 14347  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 14348  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 14349  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 14350  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
# 14351  7GRhBDsirIGkRZBtSMEzNTyDr2JQm4xx
#
# [14352 rows x 3 columns]

# %%
enrollment_id_list = required_test_users['enrollment_id'].to_list()

# %%
new_log_test = pd.read_csv('new_log_test.csv')
new_log_test.drop('Unnamed: 0', axis=1, inplace=True)
#new_log_test = new_log_test.head(10000) # Remove when running full dataset

# %%
new_log_test = new_log_test.head(10000)

# %%
new_log_test
# Out:
#       enrollment_id                 time   source       event  \
# 0                 2  2014-06-13T09:52:49   server    navigate
# 1                 2  2014-06-13T09:58:09   server      access
# 2                 2  2014-06-13T09:58:09   server      access
# 3                 2  2014-06-13T09:58:26  browser      access
# 4                 2  2014-06-13T09:58:27  browser      access
# ...             ...                  ...      ...         ...
# 9995            100  2014-06-14T04:34:28   server      access
# 9996            100  2014-06-14T04:34:29  browser  page_close
# 9997            100  2014-06-14T04:49:30   server      access
# 9998            100  2014-06-14T04:49:30  browser  page_close
# 9999            100  2014-06-14T05:05:54   server      access
#
#                                 object        date time_event
# 0     Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-06-13   09:52:49
# 1     3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-13   09:58:09
# 2     qxvBNYTfiRkNcCvM0hcGwG6hvHdQwnd4  2014-06-13   09:58:09
# 3     qxvBNYTfiRkNcCvM0hcGwG6hvHdQwnd4  2014-06-13   09:58:26
# 4     qxvBNYTfiRkNcCvM0hcGwG6hvHdQwnd4  2014-06-13   09:58:27
# ...                                ...         ...        ...
# 9995  ep57uq0N5Fxg1Irgy68ROj8HOuD4xbsi  2014-06-14   04:34:28
# 9996  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-14   04:34:29
# 9997  1Q5vBuafwY9UtwES85wN8NM0ARi2qQFS  2014-06-14   04:49:30
# 9998  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-14   04:49:30
# 9999  McmRu9AROmAUHuv4Hn6j3pvoOI8YAdOM  2014-06-14   05:05:54
#
# [10000 rows x 7 columns]

# %%
req_test = pd.read_csv("req_test.csv")
req_test.drop('Unnamed: 0', axis=1, inplace=True)
req_test
# Out:
#         enrollment_id                 time   source       event  \
# 0                  34  2014-06-22T15:58:19   server    navigate
# 1                  34  2014-06-22T16:00:51   server    navigate
# 2                  34  2014-06-22T16:00:52   server        wiki
# 3                  34  2014-06-22T16:00:58   server    navigate
# 4                  34  2014-06-22T16:02:03   server      access
# ...               ...                  ...      ...         ...
# 866994         200817  2014-07-13T14:05:51  browser       video
# 866995         200817  2014-07-13T14:07:46  browser  page_close
# 866996         200817  2014-07-13T14:07:46  browser       video
# 866997         200829  2014-07-13T17:09:01   server    navigate
# 866998         200829  2014-07-13T17:09:08   server    navigate
#
#                                   object        date time_event
# 0       Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-06-22   15:58:19
# 1       l0kj1vWrjGxi2YqQWGitPXDEoH5G5RYd  2014-06-22   16:00:51
# 2       3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-22   16:00:52
# 3       a8k7VowQW6MVkImzpiv8bqd9BAdOwCKb  2014-06-22   16:00:58
# 4       3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-22   16:02:03
# ...                                  ...         ...        ...
# 866994  Vx3tum6kPiKC1nPW9LYzM4jG1xJBUItc  2014-07-13   14:05:51
# 866995  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-07-13   14:07:46
# 866996  1x59fKeKJvw5iXjlC7DOEqL0Vdgex9ke  2014-07-13   14:07:46
# 866997  9Mur5ciTV9IBFfcPaz5c3nC1lrZaxBvG  2014-07-13   17:09:01
# 866998  Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-07-13   17:09:08
#
# [866999 rows x 7 columns]

# %%
week1, week2, week3, week4 = [], [], [], []

# %%
n = len(req_test)
for i in range(n):
    datestr = req_test.loc[i, 'date'].split('-')
    d = date(int(datestr[0]), int(datestr[1]), int(datestr[2]))
    e = req_test.loc[i, 'enrollment_id']
    if e in enrollment_id_list:
        j = enrollment_id_list.index(e)
        cid = required_test_users.loc[j, 'course_id']
        k = course_id_list.index(cid)
        row = req_test.iloc[i]
        row['date'] = d
        if start_end_dates.loc[k, 'week1_start']<=d<=start_end_dates.loc[k, 'week1_end']:
            week1.append(row)
        elif start_end_dates.loc[k, 'week2_start']<=d<=start_end_dates.loc[k, 'week2_end']:
            week2.append(row)
        elif start_end_dates.loc[k, 'week3_start']<=d<=start_end_dates.loc[k, 'week3_end']:
            week3.append(row)
        else:
            week4.append(row)
# Out:
# C:\Users\adewan\AppData\Local\Temp\ipykernel_11392\2162567302.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row['date'] = d

# %%
week1 = pd.DataFrame(week1)
week2 = pd.DataFrame(week2)
week3 = pd.DataFrame(week3)
week4 = pd.DataFrame(week4)

# %%
week1
# Out:
#         enrollment_id                 time   source       event  \
# 0                  34  2014-06-22T15:58:19   server    navigate
# 1                  34  2014-06-22T16:00:51   server    navigate
# 2                  34  2014-06-22T16:00:52   server        wiki
# 3                  34  2014-06-22T16:00:58   server    navigate
# 4                  34  2014-06-22T16:02:03   server      access
# ...               ...                  ...      ...         ...
# 865976         199075  2014-05-29T23:34:35   server    navigate
# 865977         199075  2014-05-29T23:34:42   server      access
# 865978         199075  2014-05-29T23:34:42   server      access
# 865979         199075  2014-05-29T23:35:23  browser  page_close
# 865980         199075  2014-05-29T23:35:23  browser       video
#
#                                   object        date time_event
# 0       Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-06-22   15:58:19
# 1       l0kj1vWrjGxi2YqQWGitPXDEoH5G5RYd  2014-06-22   16:00:51
# 2       3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-22   16:00:52
# 3       a8k7VowQW6MVkImzpiv8bqd9BAdOwCKb  2014-06-22   16:00:58
# 4       3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-22   16:02:03
# ...                                  ...         ...        ...
# 865976  Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-05-29   23:34:35
# 865977  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-05-29   23:34:42
# 865978  rzD0oQZc7JQ5NGqJnHItoenywlCjkolJ  2014-05-29   23:34:42
# 865979  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-05-29   23:35:23
# 865980  wT614B6qEHZ7FyR3JSkh8J7tEtVF4XL8  2014-05-29   23:35:23
#
# [232289 rows x 7 columns]

# %%
week2
# Out:
#         enrollment_id                 time  source       event  \
# 32                 34  2014-06-26T12:19:58  server      access
# 33                 34  2014-06-26T12:19:58  server    navigate
# 34                 34  2014-06-27T12:38:38  server    navigate
# 35                 34  2014-06-27T12:38:38  server      access
# 36                 34  2014-07-01T00:44:18  server    navigate
# ...               ...                  ...     ...         ...
# 862928         195455  2014-06-01T15:23:26  server    navigate
# 862929         195455  2014-06-01T15:23:45  server        wiki
# 862930         195455  2014-06-01T15:23:46  server  discussion
# 862931         195455  2014-06-01T15:23:50  server  discussion
# 862949         195537  2014-06-01T18:00:44  server    navigate
#
#                                   object        date time_event
# 32      E7o30eMHzGRRqJoJuFdot6gfswR7cNPY  2014-06-26   12:19:58
# 33      a8k7VowQW6MVkImzpiv8bqd9BAdOwCKb  2014-06-26   12:19:58
# 34      a8k7VowQW6MVkImzpiv8bqd9BAdOwCKb  2014-06-27   12:38:38
# 35      E7o30eMHzGRRqJoJuFdot6gfswR7cNPY  2014-06-27   12:38:38
# 36      Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-07-01   00:44:18
# ...                                  ...         ...        ...
# 862928  LqFccVWNL4Ys98uFgJaQdj6ZcKrPaCAe  2014-06-01   15:23:26
# 862929  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-01   15:23:45
# 862930  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-01   15:23:46
# 862931  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-06-01   15:23:50
# 862949  9Mur5ciTV9IBFfcPaz5c3nC1lrZaxBvG  2014-06-01   18:00:44
#
# [138998 rows x 7 columns]

# %%
week3
# Out:
#         enrollment_id                 time   source       event  \
# 146                34  2014-07-03T14:13:06   server    navigate
# 147                34  2014-07-03T14:13:17   server      access
# 148                34  2014-07-03T14:13:17   server      access
# 149                34  2014-07-03T14:14:25   server      access
# 150                34  2014-07-03T14:14:26  browser  page_close
# ...               ...                  ...      ...         ...
# 866745         200176  2014-02-06T13:10:31   server    navigate
# 866746         200176  2014-02-06T13:10:31   server        wiki
# 866747         200176  2014-02-06T13:10:39   server    navigate
# 866748         200176  2014-02-06T13:10:43   server    navigate
# 866749         200176  2014-02-06T13:10:49   server  discussion
#
#                                   object        date time_event
# 146     Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-07-03   14:13:06
# 147     3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-07-03   14:13:17
# 148     930872bvdoHAPATW4FUKMfPrXPCfhOc0  2014-07-03   14:13:17
# 149     cxOMs3FCbZQXEhvP7JEhchXpXFWK8OSP  2014-07-03   14:14:25
# 150     3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-07-03   14:14:26
# ...                                  ...         ...        ...
# 866745  l0kj1vWrjGxi2YqQWGitPXDEoH5G5RYd  2014-02-06   13:10:31
# 866746  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-02-06   13:10:31
# 866747  vPJ7ada7OqDfvYXMjnTQC3NExmLvWiUL  2014-02-06   13:10:39
# 866748  ykjH1bzwnUL5biZCKZGrCwLbCJ3znUdx  2014-02-06   13:10:43
# 866749  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-02-06   13:10:49
#
# [115284 rows x 7 columns]

# %%
week4
# Out:
#         enrollment_id                 time   source       event  \
# 385                34  2014-07-10T14:54:21   server    navigate
# 386                34  2014-07-10T14:54:25   server  discussion
# 387                34  2014-07-10T14:54:29   server    navigate
# 388                34  2014-07-10T14:54:30   server      access
# 389                34  2014-07-10T14:54:31   server      access
# ...               ...                  ...      ...         ...
# 866994         200817  2014-07-13T14:05:51  browser       video
# 866995         200817  2014-07-13T14:07:46  browser  page_close
# 866996         200817  2014-07-13T14:07:46  browser       video
# 866997         200829  2014-07-13T17:09:01   server    navigate
# 866998         200829  2014-07-13T17:09:08   server    navigate
#
#                                   object        date time_event
# 385     Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-07-10   14:54:21
# 386     3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-07-10   14:54:25
# 387     Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-07-10   14:54:29
# 388     3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-07-10   14:54:30
# 389     930872bvdoHAPATW4FUKMfPrXPCfhOc0  2014-07-10   14:54:31
# ...                                  ...         ...        ...
# 866994  Vx3tum6kPiKC1nPW9LYzM4jG1xJBUItc  2014-07-13   14:05:51
# 866995  3T6XwoiMKgol57cm29Rjy8FXVFcIomxl  2014-07-13   14:07:46
# 866996  1x59fKeKJvw5iXjlC7DOEqL0Vdgex9ke  2014-07-13   14:07:46
# 866997  9Mur5ciTV9IBFfcPaz5c3nC1lrZaxBvG  2014-07-13   17:09:01
# 866998  Oj6eQgzrdqBMlaCtaq1IkY6zruSrb71b  2014-07-13   17:09:08
#
# [380428 rows x 7 columns]

# %%
week1.to_csv('week1_test.csv')
week2.to_csv('week2_test.csv')
week3.to_csv('week3_test.csv')
week4.to_csv('week4_test.csv')
